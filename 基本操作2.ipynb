# %%
import torch

# %%
sample = torch.rand(3,2)

# %%
sample
# Out:
# tensor([[0.3686, 0.6916],
#         [0.2289, 0.9789],
#         [0.0717, 0.7710]])

# %%
torch.sum(sample)
# Out:
# tensor(3.1107)

# %%
torch.min(sample)
# Out:
# tensor(0.0717)

# %%
torch.max(sample)
# Out:
# tensor(0.9789)

# %%
torch.argmin(sample)
# Out:
# tensor(4)

# %%
torch.argmax(sample)
# Out:
# tensor(3)

# %%
torch.mean(sample)
# Out:
# tensor(0.5185)

# %%
torch.median(sample)
# Out:
# tensor(0.3686)

# %%
torch.sqrt(sample)
# Out:
# tensor([[0.6071, 0.8317],
#         [0.4784, 0.9894],
#         [0.2677, 0.8781]])

# %%
sample ** 2
# Out:
# tensor([[0.1359, 0.4784],
#         [0.0524, 0.9583],
#         [0.0051, 0.5944]])
